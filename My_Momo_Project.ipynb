# %% [markdown]
# <a href="https://colab.research.google.com/github/George-Opoku-Mensah/My-Momo-Project/blob/main/My_Momo_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame({
    'What':['Cash Out','Airtime','Transfer'],
    'Amount':[200,10,150]
})
print(df)
print("Total:",df['Amount'].sum())
df.plot(kind='bar',x='What',
        y='Amount')
# Out:
#        What  Amount
# 0  Cash Out     200
# 1   Airtime      10
# 2  Transfer     150
# Total: 360
# <Axes: xlabel='What'>

# %% [markdown]
# #

# %% [markdown]
# # My Momo Project-KsTU
# Total Momo spent:360 GHS
# Biggest:Cash Out 200 GHS
# Learning :How to use python for persnal finance
